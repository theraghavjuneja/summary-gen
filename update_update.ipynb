# %%
import pandas as pd

# %%
df=pd.read_csv('data_updated.csv')

# %%
df
# Out:
#       S.NO.     ORGANISATION     PSID PS CATEGORY  TEAM ID  IDEA ID  \
# 0         1            AICTE  SIH1458    Software    40481    50869
# 1         2            AICTE  SIH1458    Software    27179    50141
# 2         3            AICTE  SIH1458    Software    28982    48836
# 3         4            AICTE  SIH1458    Software     3934    39712
# 4         5            AICTE  SIH1458    Software     3103    47678
# ...     ...              ...      ...         ...      ...      ...
# 1300   1301  Open Innovation      NaN    Software     5774     2340
# 1301   1302  Open Innovation      NaN    Software    34862    26612
# 1302   1303  Open Innovation      NaN    Software    15731    23205
# 1303   1304  Open Innovation      NaN    Software    11167    14410
# 1304   1305  Open Innovation      NaN    Software    29640    20657
#
#              TEAM NAME                  TEAM LEADER NAME  COLLEGE ID  \
# 0       DYNAMIC DUDES@                     BHAVYA GROVER      145546
# ...

# %%
df2=df.drop(columns=['ORGANISATION','PSID','TEAM ID','IDEA ID','COLLEGE ID','STATUS','NODAL CENTER','TEAM NAME','TEAM LEADER NAME','COLLEGE'])

# %%
df2
# Out:
#       S.NO. PS CATEGORY                                 Problem Statements
# 0         1    Software  AI Based - Designing of Assistive portal for S...
# 1         2    Software  AI Based - Designing of Assistive portal for S...
# 2         3    Software  AI Based - Designing of Assistive portal for S...
# 3         4    Software  AI Based - Designing of Assistive portal for S...
# 4         5    Software  AI Based - Designing of Assistive portal for S...
# ...     ...         ...                                                ...
# 1300   1301    Software                                                NaN
# 1301   1302    Software                                                NaN
# 1302   1303    Software                                                NaN
# 1303   1304    Software                                                NaN
# 1304   1305    Software                                                NaN
#
# [1305 rows x 3 columns]

# %%
df2['ORGANISATION'].value_counts()
# Out:
# ORGANISATION
# AICTE, MIC-Student Innovation                               182
# Ministry of Power                                            99
# Ministry of Jal Shakti                                       74
# National Technical Research Organisation,(NTRO)              68
# Ministry of Social Justice and Empowerment                   67
# Ministry of Home Affairs                                     61
# Ministry of AYUSH                                            53
# Ministry of Defence                                          50
# Ministry of coal                                             47
# Ministry of Commerce and Industries                          47
# Indian Space Research Organisation (ISRO)                    46
# Ministry of Law and Justice                                  43
# Government of Jharkhand                                      42
# Ministry of Mines                                            37
# ...
